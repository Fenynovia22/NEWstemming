# %%
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive/Colab Notebooks/data_skripsi'
# Out:
# /content/drive/My Drive/Colab Notebooks/data_skripsi

# %%
# !ls
# Out:
#  actual_word			   PENGUJIAN_IDRISnew.ipynb
#  hasil_idris			   PENGUJIAN_INIDRISnew.ipynb
#  hasil_inidris			  'Perbandingan Stemming Idris.csv'
# 'Hasil perbandingan Idris.csv'	  'Perbandingan Stemming Inidris.csv'
# 'Hasil perbandingan Inidris.csv'   stopwords2.txt
#  IDRIS.ipynb			   stopwords.txt
#  INIDRIS.ipynb			   test_data
#  katadasarbahasaindonesia.txt	   timecomplex_idris.ipynb
#  kata_dasar_db.txt		   timecomplex_inidris.ipynb

# %%
kata_dasar = open("kata_dasar_db.txt", 'r').read()
kata_dasar = kata_dasar.split("\n")

kamus = []
for i in kata_dasar:
    kata = "{}".format(i)
    kata = kata.replace("(Nomina)", "")
    kata = kata.replace("(Adjektiva)", "")
    kata = kata.replace("(Adverbia)", "")
    kata = kata.replace("(Numeralia)", "")
    kata = kata.replace("(Pronomina)", "")
    kata = kata.replace("(Verba)", "")
    kata = kata.replace("(Preposisi)", "")
    kata = kata.replace("(Interjeksi)", "")
    kata = kata.replace("(Konjungsi)", "")
    kata = kata.replace("(Lain-lain)", "")
    kata = kata.replace("\n", "")
    kata = kata.rstrip()
    kamus.append(kata)

# fungsi untuk mengecek kata dalam tabel dictionary
def cekKamus_idris(kata):
    if kata in kamus:
        return kata
    else:
        status = 0
    return status

# fungsi untuk menghapus suffix seperti -ku, -mu, -kah, dsb
def del_inflection_suffixes_idris(kata):                                        #0
    kataAsal = kata                                                             #1
    if(re.search(r"([kl]ah|pun)$", kata, re.IGNORECASE)):                       #1
        _kata = re.sub(r"([kl]ah|pun)$", '', kata, re.IGNORECASE)               #1
        if(cekKamus_idris(_kata)):                                              #N
            return _kata                                                        #1
        else:                                                                   #1
            kata = _kata                                                        #1
    if(re.search(r'([km]u|nya)$', kata, re.IGNORECASE)):
        _kata = re.sub(r'([km]u|nya)$', '', kata, re.IGNORECASE)
        if(cekKamus_idris(_kata)):
            return _kata
    return kataAsal

# Cek Prefix Disallowed Sufixes (Kombinasi Awalan dan Akhiran yang tidak diizinkan)
def cek_prefix_disallowed_sufiks_idris(kata):
    kataAsal = kata
    # r"^(ber)[[:alpha:]](lah|an)$"
    if(re.search(r"^(ber)[^\W\d_](lah|an)$", kata, re.IGNORECASE)):
        _kata = re.sub(r"^(ber)", '', kata, re.IGNORECASE)
        return _kata
    # ^(men|di|pe|ter)[[:alpha:]](i)
    if (re.search(r"^(men|di|pe|ter)[^\W\d_](i)$", kata, re.IGNORECASE)):
        _kata = re.sub(r"^(men|di|pe|ter)", '', kata, re.IGNORECASE)
        return _kata
    return kataAsal

# Hapus Derivation Suffixes ("-i", "-an" atau "-kan")
def del_derivation_suffixes_idris(kata):
    if(re.search(r"(i|an)$", kata, re.IGNORECASE)):
        _kata = re.sub(r"(i|an)$", '', kata, re.IGNORECASE)
        if(cekKamus_idris(_kata)):
            return _kata
        elif(re.search(r"(kan)$", kata)):
            _kata = re.sub(r"(kan)$", '', kata, re.IGNORECASE)
            if(cekKamus_idris(_kata)):
                return _kata
            else:
                _kata = del_derivation_prefix_idris(_kata)
                return _kata

# Hapus Derivation Prefix ("di-", "ke-", "se-", "te-", "be-", "me-", atau "pe-")
def del_derivation_prefix_idris(kata):
    kataAsal = kata
    if(re.search(r"^(diper)", kata, re.IGNORECASE)):
        _kata = re.sub(r"^(diper)", '', kata, re.IGNORECASE)
        return _kata

    if(re.search(r"^(di|[ks]e)", kata, re.IGNORECASE)):
        _kata = re.sub(r"^(di|[ks]e)", '', kata, re.IGNORECASE)
        return _kata

    if(re.search(r"^(ke[bt]er)", kata, re.IGNORECASE)):
        _kata = re.sub(r"^(ke[bt]er)", '', kata, re.IGNORECASE)
        return _kata

    if(re.search(r"^([bt]e)", kata, re.IGNORECASE)):
        _kata = re.sub(r"^([bt]e[lr])", '', kata, re.IGNORECASE)
        if(cekKamus_idris(_kata)):
            return _kata
        _kata = re.sub(r"^([bt]e)", '', kata, re.IGNORECASE)
        return _kata

    if(re.search(r"^([mp]e)", kata, re.IGNORECASE)):
        _kata = re.sub(r"([mp]e)", '', kata, re.IGNORECASE)
        if(cekKamus_idris(_kata)):
            return _kata
        else:
            if(re.search(r"^(memper)", kata, re.IGNORECASE)):
                _kata = re.sub(r"(memper)", '', kata, re.IGNORECASE)
                if(cekKamus_idris(_kata)):
                    return _kata

            if(re.search(r"^([mp]eng)", kata, re.IGNORECASE)):
                _kata = re.sub(r"^([mp]eng)", '', kata, re.IGNORECASE)
                if(cekKamus_idris(_kata)):
                    return _kata
                else:
                    _kata = re.sub(r"([mp]eng)", 'k', kata, re.IGNORECASE)

            if(re.search(r"^([mp]eny)", kata, re.IGNORECASE)):
                _kata = re.sub(r"^([mp]eny)", 's', kata, re.IGNORECASE)

            if(re.search(r"^([mp]e[lr])", kata, re.IGNORECASE)):
                _kata = re.sub(r"^([mp]e[lr])", '', kata, re.IGNORECASE)

            if(re.search(r"^([mp]en)", kata, re.IGNORECASE)):
                _kata = re.sub(r"^([mp]en)", 't', kata, re.IGNORECASE)
                if(cekKamus_idris(_kata)):
                    return _kata
                else:
                    _kata = re.sub(r"^([mp]en)", '', kata, re.IGNORECASE)

            if(re.search(r"^([mp]em)", kata, re.IGNORECASE)):
                _kata = re.sub(r"^([mp]em)", '', kata, re.IGNORECASE)
                if(cekKamus_idris(_kata)):
                    return _kata
                else:
                    _kata = re.sub(r"^([mp]em)", 'p', kata, re.IGNORECASE)

            return _kata
    return kataAsal


def step2_idris(kata):
    kataAsal = kata
    kata = cek_prefix_disallowed_sufiks_idris(kata)
    # print("1"+str(kata))
    if(cekKamus_idris(kata)):
        return kata
    else:
        kata = del_derivation_prefix_idris(kata)
        # print("2"+str(kata))
        if(cekKamus_idris(kata)):
            return kata
        else:
            kata = del_inflection_suffixes_idris(kata)
            # print("3"+str(kata))
            if(cekKamus_idris(kata)):
                return kata
            else:
                kata = del_derivation_suffixes_idris(kata)
                # print("4"+str(kata))
                if(cekKamus_idris(kata)):
                    return kata
                else:
                    return kataAsal+" "+"(Kata Salah)"


def stemming_idris(kata):
    kataAsal = kata
    # cekKamus = cekKamus_idris(kata)
    if (cekKamus_idris(kata) != 0):
        return kata
    else:
        kata = step2_idris(kata)
        return kata

# %%
import timeit
import statistics

#setup untuk check time complexity idris dengan library timeit
SETUP_CODE = '''
from __main__ import stemming_idris
import re'''

#panjang kata untuk time complexity mulai dari 1 kata hingga 100 kata
data_length = [1, 2, 3, 4, 5, 10, 20, 30, 40, 50, 100]

total_time = []
time_average = []
time_maxs = []
time_mins = []

#cek time complexity
for a in data_length:
    print('test panjang kata '+str(a))
    times = timeit.repeat(repeat = 5,
                          number = 10000,
                          setup = SETUP_CODE,
                          stmt ='''
strings = "bercerita ujarku lupa janjiku menghubunginya terjebak durasi percakapan telepon jarak kilometer puluh enam jam perjalanan udara kabar matahari kotanya ramalan cuaca harga terkini makanan instan hasil impor tiongkok makanan kucing bicarakan samasama unsur mekanis apapun mengangkat telepon barangkali kebiasaan adiktif alam sadar enggan lelap dering telepon terjaga belasan jam kubilang ceritacerita kau tulis rubik online blog pribadimu kali membaca ceritamu terseret lubang hitam hidup narasimu kesialankulah membaca tulisan terbarumu jam tulisanmu sekuat memengaruhiku isi kepalaku gerak tanganku kehidupanku tulisanku untukmu singkat menusuk ulu hati seakan memaksaku tinggal dunia sembunyi lucunya mengonversi nyata semestinya cinta mati mendengar sayup suaranya mengumpat langitlangit kamar desau angin mengembus debudebu tirai jendela kalimat terakhirnya udara new york jakarta beku pepat menyesakkan rongga dada kalimat mulutnya sepasang kekasih jarak tema selesai mudahnya mengumpatku kasar nama binatang merta memutuskan berhenti arti berhenti salah satunya cinta mati berkepala besi kupungkiri termanipulasi sempurna mengonversi narasinya nyata menghisap rokok dengannya menyukai anggur putih whiski melarang keras menegaknya makhluk malam terjaga toko sudut gang pagi robot hatinya bolong mesin pembalas pesan romansa orangorang depresi kesepian media anonim rumah puluh jam bebas dikunjungi ditinggalkan jejakjejak sepatu kotor tetes air payung basah terjebak menguasaiku barangkali nasib sial sesiapa dicintai penulis peran hidup tulisantulisannya dunia pemeran utamanya bergantiganti wajah terbelah bicara dengannyapun tokoh cerita suaranya ujung sambungan telepon mendengar ceracauku saksama mendengarkanku fokus fokus prajurit barisan batalyon perang mendengar perintah komandannya ceritacerita ditulisnya memberiku ruang hidup menulis karenaku untukku persis citacitanya menumbuhkan ekosistem pengalaman harapan mengubahku mesin rusak mesin kau manusia kau mesin narasi kuciptakan untukmu semestinya membuatmu hidup dunia sembunyi purapura mencintaimu perasaan kupersembahkan untukmu upeti tuan puteri gunanya kau mudah menemukan lelaki senang hati melayanimu sambungan telepon ditutup jam sembilan belas menit puluh detik bergemuruh diriku merambat selasela tulang punggung menekan asam lambung memenuhi relung bergetar kudefinisi perasaan bicara dengannya mengingatnya pelukannya menghirup aroma pewangi binatu bercampur khas keringatnya pelukan kurindukan rapatrapat perkataannya dunia mencintaiku mencintaiku kadang kutukan mengenalnya membuatku percaya pepatah bilang kau memilih kau menikah kau jatuh cinta sungguh jatuh cinta lelaki mengataiku anjing apapun alasannya sepasang kekasih menatap peluk berkalikali mematahkan menyayangi umpatanumpatan terdengar indah ceria prelude in c major hidupku kerumitan semesta percikpercik api amarah ketidaknyamanan kubenci mempesona kuncup bunga mekar sore selepas hujan gila membuatku jatuh cinta mati bersamaan kemarin pagi pesawatnya mendarat new york jakarta tujuh puluh menit mengabari apaapa puluh delapan jam mengunggah gambar instagram story berisi salam perpisahan kota ditinggalinya dicintainya kedatangannya jakarta berita menyakitkan pesan keterpaksaan mengisi ruangruang kosong udara menolak kota denganku berpapasan trotoar jalan bertemu bus kota sengaja mengunjungi pagelaran seni panggung budaya terkenal kota tempattempat favoritnya tempattempat favoritku jua samasama menghindari kecanggungan kota memenuhi janjinya menjagaku jarak terdekat sayangnya janji apapun berjalan semestinya kali menemukan alasan menjaga berhenti sepasang kekasih memikirkan skenario terbaik tibatiba alam bercanda mempertemukan bungkus rokok madu habis kunyalakan balkon kamar kepulkepul asapnya memberiku inspirasi apapun kerumitan jiwa mencintai patah menunggu labalaba hantu melintas memberitahuku mengelabui canda semesta tibatiba pintu kamarku terketuk keras sialan nasib buruk selesai gila jatuh cinta perempuan depanku nggak membuatmu patah hati pelukan hey kau biar kuberikan untukmu"
string2 = strings.split(' ')
my_list = string2[:'''+str(a)+''']
for b in my_list: 
    stemming_idris(b)
''')
    time_average.append(statistics.mean(times))
    time_maxs.append(max(times))
    time_mins.append(min(times))
    total_time.append(times)
# Out:
# test panjang kata 1
# test panjang kata 2
# test panjang kata 3
# test panjang kata 4
# test panjang kata 5
# test panjang kata 10
# test panjang kata 20
# test panjang kata 30
# test panjang kata 40
# test panjang kata 50
# test panjang kata 100

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=data_length, y=time_maxs,
                    mode='lines+markers',
                    name='Time Complexity'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8c4cd848-67aa-4234-b578-a2a7ad6dc942" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c4cd848-67aa-4234-b578-a2a7ad6dc942")) {
#                     Plotly.newPlot(
#                         '8c4cd848-67aa-4234-b578-a2a7ad6dc942',
# ...

# %%
statistics.mean([1, 2, 3])
# Out:
# 2
